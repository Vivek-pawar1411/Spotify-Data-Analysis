# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/drive/MyDrive/ML Data/spotify-albums_data_2023.csv')

# %%
df1.shape
# Out:
# (438973, 26)

# %%
df1.head()
# Out:
#             track_name                track_id  track_number  duration_ms  \
# 0        Amazing Grace  6mN8nzCXWUeT5LWEcG1Utx             5       555521
# 1         Silent Night  58sgjtx3FOnBBEOd3BQE6C             8       535041
# 2      Ancient Canyons  45tQJhm0WSk5VWMZK3FsLK             1       545855
# 3  Pacha Mama Medicina  3VFD7QqkJSg0OR6yBwKl7A             6       305241
# 4      Palace Of Light  7LwJV5BEIC9BQnzvaBSyCc             7       351060
#
#   album_type  artists  total_tracks             album_name  \
# 0      album      NaN             9  Deep Peace Experience
# 1      album      NaN             9  Deep Peace Experience
# 2      album      NaN             9  Deep Peace Experience
# 3      album      NaN             9  Deep Peace Experience
# 4      album      NaN             9  Deep Peace Experience
#
#               release_date               label  ...  artist_3 artist_4  \
# 0  2015-06-09 00:00:00 UTC  Mountain Music Inc  ...       NaN      NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438973 entries, 0 to 438972
# Data columns (total 26 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_name        438971 non-null  object
#  1   track_id          438973 non-null  object
#  2   track_number      438973 non-null  int64
#  3   duration_ms       438973 non-null  int64
#  4   album_type        438973 non-null  object
#  5   artists           0 non-null       float64
#  6   total_tracks      438973 non-null  int64
#  7   album_name        438973 non-null  object
#  8   release_date      438950 non-null  object
#  9   label             438949 non-null  object
#  10  album_popularity  438973 non-null  int64
#  11  album_id          438973 non-null  object
#  12  artist_id         438973 non-null  object
#  13  artist_0          438971 non-null  object
#  14  artist_1          100485 non-null  object
#  15  artist_2          43650 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# track_name               2
# track_id                 0
# track_number             0
# duration_ms              0
# album_type               0
# artists             438973
# total_tracks             0
# album_name               0
# release_date            23
# label                   24
# album_popularity         0
# album_id                 0
# artist_id                0
# artist_0                 2
# artist_1            338488
# artist_2            395323
# artist_3            422611
# artist_4            431800
# artist_5            435028
# artist_6            436424
# artist_7            438973
# artist_8            438973
# artist_9            438973
# artist_10           438973
# artist_11           438973
# duration_sec             0
# dtype: int64

# %%
df1.shape
# Out:
# (438973, 15)

# %%
columns_to_drop = ['artist_0','artist_1', 'artist_2', 'artist_3','artist_4','artist_5','artist_6','artist_7','artist_8','artist_9','artist_10','artist_11']
df1.drop(columns_to_drop, axis=1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438973 entries, 0 to 438972
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_name        438971 non-null  object
#  1   track_id          438973 non-null  object
#  2   track_number      438973 non-null  int64
#  3   duration_ms       438973 non-null  int64
#  4   album_type        438973 non-null  object
#  5   artists           0 non-null       float64
#  6   total_tracks      438973 non-null  int64
#  7   album_name        438973 non-null  object
#  8   release_date      438950 non-null  object
#  9   label             438949 non-null  object
#  10  album_popularity  438973 non-null  int64
#  11  album_id          438973 non-null  object
#  12  artist_id         438973 non-null  object
#  13  artist_0          438971 non-null  object
#  14  duration_sec      438973 non-null  float64
# dtypes: float64(2), int64(4), object(9)
# ...

# %%
df1.drop(['artist_0','track_number','album_type',], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (438973, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438973 entries, 0 to 438972
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_name        438971 non-null  object
#  1   track_id          438973 non-null  object
#  2   duration_ms       438973 non-null  int64
#  3   artists           0 non-null       float64
#  4   total_tracks      438973 non-null  int64
#  5   album_name        438973 non-null  object
#  6   release_date      438950 non-null  object
#  7   label             438949 non-null  object
#  8   album_popularity  438973 non-null  int64
#  9   album_id          438973 non-null  object
#  10  artist_id         438973 non-null  object
#  11  duration_sec      438973 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 40.2+ MB

# %%
df1.drop(['artists','total_tracks'], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (438973, 10)

# %%
df1.fillna(0)
# Out:
#                  track_name                track_id  duration_ms  \
# 0             Amazing Grace  6mN8nzCXWUeT5LWEcG1Utx       555521
# 1              Silent Night  58sgjtx3FOnBBEOd3BQE6C       535041
# 2           Ancient Canyons  45tQJhm0WSk5VWMZK3FsLK       545855
# 3       Pacha Mama Medicina  3VFD7QqkJSg0OR6yBwKl7A       305241
# 4           Palace Of Light  7LwJV5BEIC9BQnzvaBSyCc       351060
# ...                     ...                     ...          ...
# 438968       Where She Goes  2sTDlCxmuZCTDKKk9f1qus       231704
# 438969            Europa :(  6vh4S1z08AjGipGAEsV62e        11904
# 438970                 Seda  1YnChEM51BVZ5dRhbVFEMl       190476
# 438971           Un Preview  5ixdmTpCmH5diBA1j154wN       165582
# 438972      Mercedes Carota  3TYOH7ta0101NYssoH5GlU       202635
#
#                                  album_name             release_date  \
# 0                     Deep Peace Experience  2015-06-09 00:00:00 UTC
# ...

# %%
df2=pd.read_csv('/content/drive/MyDrive/ML Data/spotify_tracks_data_2023.csv')

# %%
df2.shape
# Out:
# (438938, 3)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438938 entries, 0 to 438937
# Data columns (total 3 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                438938 non-null  object
#  1   track_popularity  438938 non-null  int64
#  2   explicit          438938 non-null  bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 7.1+ MB

# %%
df2.head()
# Out:
#                        id  track_popularity  explicit
# 0  02MBhqgR7WeeI4ZfB6Lo0i                 0     False
# 1  5j4M4gLYuUy9PVw0vsXWyq                 0     False
# 2  46EucLPJpx0QM3SCjzzdP0                 0     False
# 3  4nK2LvW3osgDT89S38Mcg6                 0     False
# 4  1Pq37WIQZDG7yNFnY5IbqG                 0     False

# %%
df2.drop(['explicit'], axis=1, inplace=True)

# %%
df2.head()
# Out:
#                        id  track_popularity
# 0  02MBhqgR7WeeI4ZfB6Lo0i                 0
# 1  5j4M4gLYuUy9PVw0vsXWyq                 0
# 2  46EucLPJpx0QM3SCjzzdP0                 0
# 3  4nK2LvW3osgDT89S38Mcg6                 0
# 4  1Pq37WIQZDG7yNFnY5IbqG                 0

# %%
df3=pd.read_csv('/content/drive/MyDrive/ML Data/spotify_artist_data_2023.csv')

# %%
df3.shape
# Out:
# (37012, 12)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37012 entries, 0 to 37011
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 37012 non-null  object
#  1   name               37012 non-null  object
#  2   artist_popularity  37012 non-null  int64
#  3   artist_genres      37012 non-null  object
#  4   followers          37012 non-null  int64
#  5   genre_0            10947 non-null  object
#  6   genre_1            4820 non-null   object
#  7   genre_2            2440 non-null   object
#  8   genre_3            1365 non-null   object
#  9   genre_4            718 non-null    object
#  10  genre_5            0 non-null      float64
#  11  genre_6            0 non-null      float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.4+ MB

# %%
df3.isnull().sum()
# Out:
# id                       0
# name                     0
# artist_popularity        0
# artist_genres            0
# followers                0
# genre_0              26065
# genre_1              32192
# genre_2              34572
# genre_3              35647
# genre_4              36294
# genre_5              37012
# genre_6              37012
# dtype: int64

# %%
columns_to_drop1 = ['genre_0','genre_1','genre_2','genre_3','genre_4','genre_5','genre_6']
df3.drop(columns_to_drop1, axis=1, inplace=True)

# %%
df3.shape
# Out:
# (37012, 5)

# %%
df3.head()
# Out:
#                        id                   name  artist_popularity  \
# 0  6GkSLJj5CGLIckLIb8J4LR      Late Night Fights                  0
# 1  1N0VwQy5PRJymrRvlRzDIj       Sub Par All Star                  0
# 2  4Ch4BIKKwMJsiu1oVLDwpX  Nirvana Meditation 8D                  0
# 3  5h2iINTOvhghVcpIzrztPP      Red Hot Rebellion                  0
# 4  7dE2MLL2SaI6MujpU5HFVi   Nirvana Tribute Band                  0
#
#           artist_genres  followers
# 0  ['minneapolis punk']        184
# 1     ['antiviral pop']        491
# 2                ['8d']         56
# 3       ['action rock']        394
# 4           ['tribute']        230

# %%
df1.to_csv("Spotify_albums.csv")

# %%
df2.to_csv("Spotify_track.csv")

# %%
df3.to_csv("Spotify_artists.csv")
